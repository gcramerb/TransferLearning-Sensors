# %% [markdown]
# ### Data analysis:

# %%
dataset = 'Ucihar'
file = os.path.join(inPath, f'{dataset}_f25_t2.npz')
with np.load(file,allow_pickle=True) as tmp:
    X = tmp['X']
    y = tmp['y']
    folds = tmp['folds']
for fold_i in folds:
    pd.value_counts(y[fold_i[1]]).plot()
pd.value_counts(y)
# Out:
# Ucihar-laying               1944
# Ucihar-standing             1904
# Ucihar-sitting              1777
# Ucihar-walking              1722
# Ucihar-ascending stairs     1544
# Ucihar-descending stairs    1406
# dtype: int64

# %%
dataset = 'Uschad'
file = os.path.join(inPath, f'{dataset}_f25_t2.npz')
with np.load(file,allow_pickle=True) as tmp:
    X = tmp['X']
    y = tmp['y']
    folds = tmp['folds']
for fold_i in folds:
    pd.value_counts(y[fold_i[1]]).plot()
pd.value_counts(y)
# Out:
# Uschad-sleeping           3610
# Uschad-walking forward    3555
# Uschad-sitting            1870
# Uschad-standing           1610
# Uschad-walking down        358
# Uschad-walking up          104
# dtype: int64

# %%
dataset = 'Dsads'
file = os.path.join(inPath, f'{dataset}_f25_t2.npz')
with np.load(file,allow_pickle=True) as tmp:
    X = tmp['X']
    y = tmp['y']
    folds = tmp['folds']
for fold_i in folds:
    pd.value_counts(y[fold_i[1]]).plot()
pd.value_counts(y)
# Out:
# Dsads-walking              1440
# Dsads-lying on back        1440
# Dsads-lying on right       1440
# Dsads-descending stairs    1440
# Dsads-sitting              1440
# Dsads-ascending stairs     1440
# Dsads-standing             1440
# dtype: int64

# %%
#plt.savefig('../figures/act_dist6act.png')
